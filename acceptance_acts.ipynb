# %%
from act_utils import main

if __name__ == "__main__":
    await main()
# Out:
# Получено 0 документов, offset: 0
# Последняя страница: получено 14 документов
# Всего получено 14 документов за период 2025-09-30 - 2025-10-10
# Аккаунт Даниелян: получено 14 документов act-income-mp
# Последняя страница: получено 30 документов
# Всего получено 30 документов за период 2025-09-30 - 2025-10-10
# Аккаунт Даниелян: получено 30 документов act-income
# Получено 0 документов, offset: 0
# Последняя страница: получено 25 документов
# Всего получено 25 документов за период 2025-09-30 - 2025-10-10
# Аккаунт Вектор: получено 25 документов act-income-mp
# Последняя страница: получено 48 документов
# Всего получено 48 документов за период 2025-09-30 - 2025-10-10
# Аккаунт Вектор: получено 48 документов act-income
# Получено 0 документов, offset: 0
# Последняя страница: получено 30 документов
# Всего получено 30 документов за период 2025-09-30 - 2025-10-10
# Аккаунт Оганесян: получено 30 документов act-income-mp
# Последняя страница: получено 32 документов
# ...
